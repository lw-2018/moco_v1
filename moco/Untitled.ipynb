# %%
import torch

# %%
import torch
import torch.nn as nn
a=nn.Sequential(nn.Linear(10, 100), nn.ReLU())

# %%
import copy

# %%
b = copy.deepcopy(a)

# %%
a
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=100, bias=True)
#   (1): ReLU()
# )

# %%
a.parameters
# Out:
# <bound method Module.parameters of Sequential(
#   (0): Linear(in_features=10, out_features=100, bias=True)
#   (1): ReLU()
# )>

# %%
for p in a.parameters():
    p.data = p.data*0

# %%
for e in b.parameters():
    print(e)
# Out:
# Parameter containing:
# tensor([[ 2.9043e-01, -6.3951e-02, -2.3678e-01,  1.7025e-01, -1.9661e-01,
#          -1.9583e-01,  1.1046e-01,  2.7310e-01,  2.0687e-02,  3.1638e-02],
#         [-1.4216e-01,  1.7895e-01, -1.7383e-01,  1.6698e-01,  1.1864e-01,
#           5.7874e-02, -2.1746e-01, -1.9264e-01, -1.4998e-01,  1.5578e-01],
#         [ 2.3189e-02, -1.5701e-01, -9.2842e-02, -4.7755e-02,  3.1155e-01,
#           1.4442e-01,  9.2451e-02, -1.2475e-01,  1.7427e-01, -3.0921e-01],
#         [-3.7190e-02,  5.2178e-02, -2.0675e-01,  1.5666e-01,  2.8106e-01,
#          -8.9760e-02, -1.3543e-01,  2.5150e-01,  2.0050e-01, -2.1077e-02],
#         [ 2.0160e-01,  2.3396e-01,  1.4470e-01,  1.1466e-01, -3.4957e-02,
#          -1.8119e-01, -2.0590e-01,  1.9859e-01, -1.7721e-01,  6.0330e-02],
#         [-9.8043e-02,  1.3880e-01, -2.0448e-01,  2.1813e-01,  4.3902e-02,
#           3.3989e-02, -2.4123e-01,  4.8390e-02, -2.3766e-01, -1.7030e-01],
# ...
